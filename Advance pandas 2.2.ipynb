# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KIRTI RAJ PRADHAN'

# %%
os.chdir("C:\\Users\\KIRTI RAJ PRADHAN\\Downloads")

# %%
pd.read_excel("liver.xlsx")
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df=pd.read_excel("liver.xlsx")

# %%
df
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df.head()            #1st 5 observation
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes

# %%
df.tail()    #last 5 observation
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df.shape     #dimension of data frame
# Out:
# (10, 6)

# %%
df.size    #Return an int representing the number of elements
# Out:
# 60

# %%
df.columns   #1st option to get (column name /variable name)
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'TP', 'LiverPatient'], dtype='object')

# %%
df.keys()    #2nd option to get (column name/variable name)
# Out:
# Index(['Age', 'Gender', 'TB', 'DB', 'TP', 'LiverPatient'], dtype='object')

# %%
# Data types of each column
df.dtypes
# Out:
# Age               int64
# Gender           object
# TB              float64
# DB              float64
# TP              float64
# LiverPatient     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           10 non-null     int64
#  1   Gender        10 non-null     object
#  2   TB            10 non-null     float64
#  3   DB            10 non-null     float64
#  4   TP            8 non-null      float64
#  5   LiverPatient  10 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 608.0+ bytes

# %% [markdown]
# # checking ,missing values

# %%
df.isnull().sum()
# Out:
# Age             0
# Gender          0
# TB              0
# DB              0
# TP              2
# LiverPatient    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# Age             0
# Gender          0
# TB              0
# DB              0
# TP              2
# LiverPatient    0
# dtype: int64

# %%
df.TB      #option1   accessing columns
# Out:
# 0    0.7
# 1    7.3
# 2    7.3
# 3    1.0
# 4    3.9
# 5    1.8
# 6    0.9
# 7    4.5
# 8    0.9
# 9    3.6
# Name: TB, dtype: float64

# %%
df["TB"]   #option2   accessing columns
# Out:
# 0    0.7
# 1    7.3
# 2    7.3
# 3    1.0
# 4    3.9
# 5    1.8
# 6    0.9
# 7    4.5
# 8    0.9
# 9    3.6
# Name: TB, dtype: float64

# %%
df["TB"].values     #output as array
# Out:
# array([0.7, 7.3, 7.3, 1. , 3.9, 1.8, 0.9, 4.5, 0.9, 3.6])

# %%
#accessing multiple columns
df[["TB","DB"]]
# Out:
#     TB   DB
# 0  0.7  0.1
# 1  7.3  4.1
# 2  7.3  4.1
# 3  1.0  0.4
# 4  3.9  2.0
# 5  1.8  0.7
# 6  0.9  0.2
# 7  4.5  0.3
# 8  0.9  0.3
# 9  3.6  0.1

# %%
df[["TB","DB"]].values
# Out:
# array([[0.7, 0.1],
#        [7.3, 4.1],
#        [7.3, 4.1],
#        [1. , 0.4],
#        [3.9, 2. ],
#        [1.8, 0.7],
#        [0.9, 0.2],
#        [4.5, 0.3],
#        [0.9, 0.3],
#        [3.6, 0.1]])

# %%
#drop a row or column by using axis=0 for row and axis=1 for column
df1=df.drop(0,axis=0)
df1
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df2=df.drop([0,1,2,3],axis=0)
df2
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df2=df.drop(index=[0,1,2])
df2
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df1=df.drop("TB",axis=1)
df1
# Out:
#    Age  Gender   DB   TP LiverPatient
# 0   65  Female  0.1  6.8          Yes
# 1   62    Male  4.1  7.0          Yes
# 2   62    Male  4.1  7.0          Yes
# 3   58    Male  0.4  6.8          Yes
# 4   72    Male  2.0  NaN          Yes
# 5   46    Male  0.7  7.6          Yes
# 6   26  Female  0.2  4.5           No
# 7   29  Female  0.3  6.3          Yes
# 8   17    Male  0.3  5.4           No
# 9   29    Male  0.1  NaN           No

# %%
df2=df.drop(["TB","DB"],axis=1)
df2
# Out:
#    Age  Gender   TP LiverPatient
# 0   65  Female  6.8          Yes
# 1   62    Male  7.0          Yes
# 2   62    Male  7.0          Yes
# 3   58    Male  6.8          Yes
# 4   72    Male  NaN          Yes
# 5   46    Male  7.6          Yes
# 6   26  Female  4.5           No
# 7   29  Female  6.3          Yes
# 8   17    Male  5.4           No
# 9   29    Male  NaN           No

# %%
df1=df.drop(columns="TB")
df1
# Out:
#    Age  Gender   DB   TP LiverPatient
# 0   65  Female  0.1  6.8          Yes
# 1   62    Male  4.1  7.0          Yes
# 2   62    Male  4.1  7.0          Yes
# 3   58    Male  0.4  6.8          Yes
# 4   72    Male  2.0  NaN          Yes
# 5   46    Male  0.7  7.6          Yes
# 6   26  Female  0.2  4.5           No
# 7   29  Female  0.3  6.3          Yes
# 8   17    Male  0.3  5.4           No
# 9   29    Male  0.1  NaN           No

# %%
df2=df.drop(columns=["TB","DB"])
df2
# Out:
#    Age  Gender   TP LiverPatient
# 0   65  Female  6.8          Yes
# 1   62    Male  7.0          Yes
# 2   62    Male  7.0          Yes
# 3   58    Male  6.8          Yes
# 4   72    Male  NaN          Yes
# 5   46    Male  7.6          Yes
# 6   26  Female  4.5           No
# 7   29  Female  6.3          Yes
# 8   17    Male  5.4           No
# 9   29    Male  NaN           No

# %%
df["IB"]=df["TB"]-df["DB"]
df                                       # adding a new columns
# Out:
#    Age  Gender   TB   DB   TP LiverPatient   IB
# 0   65  Female  0.7  0.1  6.8          Yes  0.6
# 1   62    Male  7.3  4.1  7.0          Yes  3.2
# 2   62    Male  7.3  4.1  7.0          Yes  3.2
# 3   58    Male  1.0  0.4  6.8          Yes  0.6
# 4   72    Male  3.9  2.0  NaN          Yes  1.9
# 5   46    Male  1.8  0.7  7.6          Yes  1.1
# 6   26  Female  0.9  0.2  4.5           No  0.7
# 7   29  Female  4.5  0.3  6.3          Yes  4.2
# 8   17    Male  0.9  0.3  5.4           No  0.6
# 9   29    Male  3.6  0.1  NaN           No  3.5

# %%
df=df.drop("IB",axis=1)
df
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df.drop(columns="TB",inplace=True)
df
# Out:
#    Age  Gender   DB   TP LiverPatient
# 0   65  Female  0.1  6.8          Yes
# 1   62    Male  4.1  7.0          Yes
# 2   62    Male  4.1  7.0          Yes
# 3   58    Male  0.4  6.8          Yes
# 4   72    Male  2.0  NaN          Yes
# 5   46    Male  0.7  7.6          Yes
# 6   26  Female  0.2  4.5           No
# 7   29  Female  0.3  6.3          Yes
# 8   17    Male  0.3  5.4           No
# 9   29    Male  0.1  NaN           No

# %%
df=pd.read_excel("liver.xlsx")

# %%
df
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
#sort function
df.sort_values(by="DB",ascending=True)
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 9   29    Male  3.6  0.1  NaN           No
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 3   58    Male  1.0  0.4  6.8          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes

# %%
df.sort_values(by="Age",ascending=True)
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 8   17    Male  0.9  0.3  5.4           No
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 9   29    Male  3.6  0.1  NaN           No
# 5   46    Male  1.8  0.7  7.6          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 0   65  Female  0.7  0.1  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes

# %%
df.sort_values(by="TB",ascending=True)
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 8   17    Male  0.9  0.3  5.4           No
# 3   58    Male  1.0  0.4  6.8          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 9   29    Male  3.6  0.1  NaN           No
# 4   72    Male  3.9  2.0  NaN          Yes
# 7   29  Female  4.5  0.3  6.3          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes

# %%
df.sort_values(by="TP",ascending=True)
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 6   26  Female  0.9  0.2  4.5           No
# 8   17    Male  0.9  0.3  5.4           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 0   65  Female  0.7  0.1  6.8          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 9   29    Male  3.6  0.1  NaN           No

# %%
df.sort_values(by="TP",ascending=False)
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 5   46    Male  1.8  0.7  7.6          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 0   65  Female  0.7  0.1  6.8          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 6   26  Female  0.9  0.2  4.5           No
# 4   72    Male  3.9  2.0  NaN          Yes
# 9   29    Male  3.6  0.1  NaN           No

# %%
df1=df.drop([0,1,2],axis=0)
df1
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df.sort_values(by="DB",ascending=True)
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 9   29    Male  3.6  0.1  NaN           No
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 3   58    Male  1.0  0.4  6.8          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes

# %%
df.sort_values(by="DB",ascending=False)
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 6   26  Female  0.9  0.2  4.5           No
# 0   65  Female  0.7  0.1  6.8          Yes
# 9   29    Male  3.6  0.1  NaN           No

# %%
#data extraction
df["Gender"]=="Male"
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7    False
# 8     True
# 9     True
# Name: Gender, dtype: bool

# %%
df[df["Gender"]=="Male"]
# Out:
#    Age Gender   TB   DB   TP LiverPatient
# 1   62   Male  7.3  4.1  7.0          Yes
# 2   62   Male  7.3  4.1  7.0          Yes
# 3   58   Male  1.0  0.4  6.8          Yes
# 4   72   Male  3.9  2.0  NaN          Yes
# 5   46   Male  1.8  0.7  7.6          Yes
# 8   17   Male  0.9  0.3  5.4           No
# 9   29   Male  3.6  0.1  NaN           No

# %%
df["TB"]>=1
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: TB, dtype: bool

# %%
df[df["TB"]>=1]
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 7   29  Female  4.5  0.3  6.3          Yes
# 9   29    Male  3.6  0.1  NaN           No

# %%
male_data=df[df["Gender"]=="Male"]
male_data
# Out:
#    Age Gender   TB   DB   TP LiverPatient
# 1   62   Male  7.3  4.1  7.0          Yes
# 2   62   Male  7.3  4.1  7.0          Yes
# 3   58   Male  1.0  0.4  6.8          Yes
# 4   72   Male  3.9  2.0  NaN          Yes
# 5   46   Male  1.8  0.7  7.6          Yes
# 8   17   Male  0.9  0.3  5.4           No
# 9   29   Male  3.6  0.1  NaN           No

# %%
df[df["Age"]>=70]
# Out:
#    Age Gender   TB   DB  TP LiverPatient
# 4   72   Male  3.9  2.0 NaN          Yes

# %%
filter1=df[(df["Age"]>=65) | (df["Gender"]=="Female")]

# %%
filter1
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes

# %%
filter2=df[(df["LiverPatient"]=="Yes") & (df["Age"]>=70)]

# %%
filter2
# Out:
#    Age Gender   TB   DB  TP LiverPatient
# 4   72   Male  3.9  2.0 NaN          Yes

# %%
filter3=df[(df["Gender"]=="Female") | (df["Age"]>=35) & (df["DB"]<=6)]
filter3
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes

# %%
df
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
#iloc get 1st row
df.iloc[0]
# Out:
# Age                 65
# Gender          Female
# TB                 0.7
# DB                 0.1
# TP                 6.8
# LiverPatient       Yes
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# Age               29
# Gender          Male
# TB               3.6
# DB               0.1
# TP               NaN
# LiverPatient      No
# Name: 9, dtype: object

# %%
df.iloc[[1,2,3]]
# Out:
#    Age Gender   TB   DB   TP LiverPatient
# 1   62   Male  7.3  4.1  7.0          Yes
# 2   62   Male  7.3  4.1  7.0          Yes
# 3   58   Male  1.0  0.4  6.8          Yes

# %%
df
# Out:
#    Age  Gender   TB   DB   TP LiverPatient
# 0   65  Female  0.7  0.1  6.8          Yes
# 1   62    Male  7.3  4.1  7.0          Yes
# 2   62    Male  7.3  4.1  7.0          Yes
# 3   58    Male  1.0  0.4  6.8          Yes
# 4   72    Male  3.9  2.0  NaN          Yes
# 5   46    Male  1.8  0.7  7.6          Yes
# 6   26  Female  0.9  0.2  4.5           No
# 7   29  Female  4.5  0.3  6.3          Yes
# 8   17    Male  0.9  0.3  5.4           No
# 9   29    Male  3.6  0.1  NaN           No

# %%
df.iloc[[1,2],[0,1]]
# Out:
#    Age Gender
# 1   62   Male
# 2   62   Male

# %%
#select the 4th row and 3rd column
df.iloc[[3],[2]]
# Out:
#     TB
# 3  1.0

# %%
v=df.iloc[[3],[2]]
v
# Out:
#     TB
# 3  1.0

# %%
df.iloc[0:8,0:3]
# Out:
#    Age  Gender   TB
# 0   65  Female  0.7
# 1   62    Male  7.3
# 2   62    Male  7.3
# 3   58    Male  1.0
# 4   72    Male  3.9
# 5   46    Male  1.8
# 6   26  Female  0.9
# 7   29  Female  4.5

# %%
#loc
df.loc[0]
# Out:
# Age                 65
# Gender          Female
# TB                 0.7
# DB                 0.1
# TP                 6.8
# LiverPatient       Yes
# Name: 0, dtype: object

# %%
df.loc[-1]  #inverse indexing is not applicable
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 df.loc[-1]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df.loc[[5,6],'TB':'TP']
# Out:
#     TB   DB   TP
# 5  1.8  0.7  7.6
# 6  0.9  0.2  4.5

# %%
df.loc[:,"TB"]
# Out:
# 0    0.7
# 1    7.3
# 2    7.3
# 3    1.0
# 4    3.9
# 5    1.8
# 6    0.9
# 7    4.5
# 8    0.9
# 9    3.6
# Name: TB, dtype: float64

# %%
df.loc[2,"Age"]
# Out:
# 62

# %%
df.iloc[2,0]
# Out:
# 62

# %%
df.iloc[[4,5],0:4]
# Out:
#    Age Gender   TB   DB
# 4   72   Male  3.9  2.0
# 5   46   Male  1.8  0.7

# %%
df.loc[[4,5],"Age":"DB"]
# Out:
#    Age Gender   TB   DB
# 4   72   Male  3.9  2.0
# 5   46   Male  1.8  0.7

# %%
l1=df.set_index("TB")

# %%
l1
# Out:
#      Age  Gender   DB   TP LiverPatient
# TB
# 0.7   65  Female  0.1  6.8          Yes
# 7.3   62    Male  4.1  7.0          Yes
# 7.3   62    Male  4.1  7.0          Yes
# 1.0   58    Male  0.4  6.8          Yes
# 3.9   72    Male  2.0  NaN          Yes
# 1.8   46    Male  0.7  7.6          Yes
# 0.9   26  Female  0.2  4.5           No
# 4.5   29  Female  0.3  6.3          Yes
# 0.9   17    Male  0.3  5.4           No
# 3.6   29    Male  0.1  NaN           No

# %%
l1.loc[0.9]
# Out:
#      Age  Gender   DB   TP LiverPatient
# TB
# 0.9   26  Female  0.2  4.5           No
# 0.9   17    Male  0.3  5.4           No

# %%
l1.reset_index()
# Out:
#     TB  Age  Gender   DB   TP LiverPatient
# 0  0.7   65  Female  0.1  6.8          Yes
# 1  7.3   62    Male  4.1  7.0          Yes
# 2  7.3   62    Male  4.1  7.0          Yes
# 3  1.0   58    Male  0.4  6.8          Yes
# 4  3.9   72    Male  2.0  NaN          Yes
# 5  1.8   46    Male  0.7  7.6          Yes
# 6  0.9   26  Female  0.2  4.5           No
# 7  4.5   29  Female  0.3  6.3          Yes
# 8  0.9   17    Male  0.3  5.4           No
# 9  3.6   29    Male  0.1  NaN           No

# %%
df1=df.loc[df["DB"]>=3.7,["Age","DB","LiverPatient"]]
df1
# Out:
#    Age   DB LiverPatient
# 1   62  4.1          Yes
# 2   62  4.1          Yes
